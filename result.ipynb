# %%
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine
from cleans import clean_meters_property_name, clean_energy_property_name, clean_area_property_name, \
    clean_money_property_name, clean_weight_property_name
# Out:
# 1
# ['м2']

# %%
database = "db_ua"
user = "apiv2"
password = "35GMHdDP9DLuKtnV"
host = "34.141.85.48"
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:3306/{database}")

# %%
df = pd.read_sql_table("aimap_object_properties", engine)

# %%
def clean_units(df):
    # df["units"] = df["units"].str.replace("(\d*,\d*\s)|(|,)(\d*\s)|(|,)(\d*\W\d*)|(|,)(\d*\w)|(|,)(\d*,\d*)", "", flags=re.IGNORECASE)
    df["units"] = df["units"].str.replace(
        "((^[\d.,\s\/-]*)|(\d*\(.*-\s\d*,\d*\s)|(^Шпаклювання)\s*\W*\d*,\d*\s|()(^гараж\d*,\d*\s)|"
        "(^Шпаклівка\s*\W*\s\d*,\s\d*\s*)|(^Складські)\s\W*\d*|\W*,\s|\W*\s\d*,\d*\s|^виробництво\sплит\sДСП|"
        "^виробництво\s\W*\w*|\(\W*\)\s|\sзберігання|\s-\W\s\W*)", "", flags=re.IGNORECASE)
    df["units"] = df["units"].str.replace(
        "(\s\(основна\)|\(підсобна\)|\sкотельні|сушильних\sкамер|"
        "\(І\sчерга.*|приміщення\s\d*|\(складських.*|"
        "\(.*|^Офісно-\W+\d\W\s\W+\d*,\W\d;\s\W*\d\W\s\W*\d*\s)", "", flags=re.IGNORECASE)
    df["units"] = df["units"].str.replace(
        "((|,)(поверх\s\d*-го\sблоку\s\d\Wти\sповерхової\sбудівлі)$|"
        "(|,)(на четвертому поверсі чотириповерхового житлового будинку)$|(|,)(х\d*)$|(|,)(\Wтехнічний поверх)$|"
        "(|,)(будівлі\sз\sтехнічним\sповерхом\s\d*,\d*)$|(|,)(цокольмансарда)$|"
        "(|,)(на\sпершому\sповерсі\sчотириповерхового\sжитлового\sбудинку)$|(|,)(з\sмансардою)$|(|,)(\W\s\d*,\d*)$|"
        "(|,)()$|(|,)((\Wмансарда\Wпідвал|\Wмансарда))$|(|,)(третій\sповерх\sчотирьохповерхової\sбудівлі)$|"
        "(|,)(й\sповерх\sта\sдругий\sрівень\s\d-го\sповерху)$|(|,)(%)$|(|,)(На\s\d\sповерсі \d-и\sповерхового\sбудинку)$|"
        "(|,)(цокольний\W\d*)$|(|,)(\)\s\d*\W\s\d\)\s\d*\W\s\d\)\s\d*)$|(|,)(\d*)$|(|,)(поверх\s\d\sповерхового\sбудинку)$|"
        "(|,)(т\sв\sзміну,теплова\sпотужність\sМвт0,6котел\sпаровий\sавтоматизований\sна\sтвердому\sпаливі\sз\sвбудованим"
        "\sекономайзером\s1штвид\sпалива-\sтверде\sпаливо)$|(|,)((один\sта\sмансарда|один\sз\sмансардою|з\sмансардою\sу"
        "\sдвох\sрівня|\W\sмансарда|\Wцокольний\Wмансардний|\Wмансардний\sповерх\sта\sпідвал|й\sповерх\sта\sвлаштований"
        "\sв\sрівні\s\d-го\s\d-й\sповер|з\sпідвалом|\Wпідвал|\Wтехповер|на\sпершому\sповерсі|підвальне\sв\sчотириповерхому"
        "\sжитловому\sбудинку|\W+1))$|(|,)(\Wпідвал)$|(|,)(Залізобетонні\sс\/п\sта\sдерев'яні\sшпали)$|(|,)(цоколь\W\d)$|"
        "(|,)(\W\d\W)$|(|,)(й\sповерх\s\d-ти\sповерхового\sжитлового\sбудинку)$|(повер)$|(з\sцокольним\sта\sмансардними\sповерхами)$|"
        "(цокольний\s\W\s\d\sповер\\|цокольний\s\W\s\d\sповер)$|(х\d*\sголів)$|(\Wмансарда\Wпогреб)$|(технічний\sповер)$|"
        "(\Wтехнічний)$|(\WМАНСАРДНИЙ)$|(|,)(поверхів\sз\sцокольним\sповерхом)$|(на першому  поверсі дев'ятиповерхового житлового будинку)$|"
        "(\W\s\d,\d)$|(х\d*)$|(цокольний поверх 5-ти поверхової будівлі)$|(металева конструкція)$|(індивідуальне газове)$|"
        "(металеві конструкції з утепленням)$|(плоска утеплена покрівляПВХ мембрана)$|(й\sта\sвлаштований\sу\sпросторі\s"
        "\d-го\s\sчетвертий\sповерхи)$|(на\sпершому\sповерсі\sдев'ятиповерхового\sжитлового\sбудинку)$|()$|(\+)$|"
        "((\+мансарний\+цокольний\+підвальний|\+мансардний\+підвальний\+цокольний))$|(на першому\sповерсі\s"
        "\d-поверхового\sжитлового\sбудинку)$|(й\s;\s\d-й)$|(\;)$|(й\sта\s\d-й)$|(камінь\sчерепашник)$|"
        "(одноповерхова квартира на 1-му поверсі 9-ти поверхового будинку)$|(Бетонні блоки)$|(й поверх \d-и поверхового будинку)$|"
        "(з підвалом і надбудовою)$|^(ІІ - основна будівляприбудова завантажувальної зони - ІІІ)$|(на \d-му\sповерсі\s"
        "\d-поверхового\sжитлового\sбудинку)$|(\W\sмансардний)$|(Цокольний\sповерх\sдвоповерхового\sбудинку)$|"
        "(з\sмансардним\sповерхом)$|(й\sповерх\s\d-поверхового\sбудинку)$|(на\sпершому\sповерсі\sодноповерхового\sжитлового\sбудинку)$|"
        "(;\s\d*\/\d*;\s\d\/\d;\s\d*;)$|((підвал\s\W|підвал\W|ПІДВАЛ\W))$|(з\sцоколем)$|(й та влаштований у просторі 4-го 5-й поверхи)$|"
        "(двоповерхова \W одноповерхова прибудова)$|(квартира розташована на третьому поверсі шестиповерхового багатоквартирного житлового будинку)$|"
        "(три з технічним поверхом з терасою та підвалом)$|(підвалу \d-ти пов. будівлі)$|(поверх житлового будинку)$|(поверхи з цокольним поверхом)$|"
        "(\Wцоколь)$|(з підвалом та мансардою)$|(й поверх \d-ти поверхового будинку)$|(\W\d*)$|(\W\s\d*,\d*\W)$|(\Wмансарда\Wцокольний)$|(\W\s\d*\W)$|"
        "(й та \d-й поверх \d-ти поверхового будинку)$|(цоколь\W)$|(на \d поверсі \d-поверхового житлового будинку)$|(підвал\W\d-ий)$|(\Wпідвальний)$|"
        "(з\sмансардним)$|(відвантаження в зміну)$|)", "", flags=re.IGNORECASE)
    # df["units"] = df["units"].str.replace("х\d*\sмм\d\s-\s\d,\d*", "мм2", flags=re.IGNORECASE)
    # df['units'] = df['units'].replace("м2)", "м2")
    # df['units'] = df['units'].replace("Шпаклювання стін та укосів, 356,05 м2", "м2")
    # df['units'] = df['units'].replace("Шпаклювання стін та укосів356,05 м2", "м2")
    # df['units'] = df['units'].replace("АВБбШВ 4х95 мм2", "м2")
    # df['units'] = df['units'].replace("АВБбШВ 4х35 мм2 - 29,0", "м2")
    # df['units'] = df['units'].replace("Шпаклівка стін0 м2", "м2")
    # df['units'] = df['units'].replace("гаражм2", "м2")
    # df['units'] = df['units'].replace("торгова площа 37,91м2", "м2")
    # df['units'] = df['units'].replace("торгівельна площам2", "м2")
    # df['units'] = df['units'].replace("Адмінбудинокм2", "м2")
    # df['units'] = df['units'].replace("Цех- складм2", "м2")
    # df['units'] = df['units'].replace("Допоміжна площам2", "м2")
    # df['units'] = df['units'].replace("Загальна площа", "м2")
    # df['units'] = df['units'].replace("(303,53м2 -1-й пусковий комплекс; 1144,80м2- 2-й пусковий комплекс)", "м2")
    # df['units'] = df['units'].replace("Заповнення віконних прорізів готовими блоками площею до 3 м2 з металопластику", "м2")
    return df

# %%
def clean_units_2(df):
    # df["units"] = df["units"].str.replace("(\d*,\d*\s)|(|,)(\d*\s)|(|,)(\d*\W\d*)|(|,)(\d*\w)|(|,)(\d*,\d*)", "", flags=re.IGNORECASE)
    df["units"] = df["units"].str.replace(
        "((^[\d.,\s\/-]*)|(\d*\(.*-\s\d*,\d*\s)|(^Шпаклювання)\s*\W*\d*,\d*\s|()(^гараж\d*,\d*\s)|"
        "(^Шпаклівка\s*\W*\s\d*,\s\d*\s*)|(^Складські)\s\W*\d*|\W*,\s|\W*\s\d*,\d*\s|^виробництво\sплит\sДСП|"
        "^виробництво\s\W*\w*|\(\W*\)\s|\sзберігання|\s-\W\s\W*)", "", flags=re.IGNORECASE)
    return df

# %%
property_value_df = df[df["property_value"].notna()]

# %%
property_value_df["normalize_property"] = property_value_df["property"]
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\3568013040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df["normalize_property"] = property_value_df["property"]

# %%
property_value_df.dropna(subset=['property_value'])
# Out:
#               id  aimap_id            property property_value  \
# 0              1         1  Кількість поверхів              0
# 1              2         1               Площа              0
# 2              3         2  Кількість поверхів              0
# 3              4         2               Площа              0
# 4              5         3  Кількість поверхів             26
# ...          ...       ...                 ...            ...
# 3353509  3650419   3052965           Фундамент          Бетон
# 3353510  3650420   3052965             Підлоги        Ламінат
# 3353511  3650421   3052965            Покриття       Руберойд
# 3353512  3650422   3052965               Сходи        Бетонні
# 3353513  3650423   3052965        Сміттєпровід            Так
#
#          normalize_property
# 0        Кількість поверхів
# 1                     Площа
# 2        Кількість поверхів
# 3                     Площа
# 4        Кількість поверхів
# ...                     ...
# ...

# %%
property_value_df['property_value'] = property_value_df['property_value'].str.strip()
property_value_df = property_value_df[property_value_df['property_value'] != ""]
property_value_df = property_value_df[property_value_df['property_value'] != " "]
property_value_df = property_value_df[property_value_df['property_value'] != "0"]
property_value_df = property_value_df[property_value_df['property_value'] != "-"]
property_value_df = property_value_df[property_value_df['property_value'] != " - "]
property_value_df = property_value_df[property_value_df['property_value'] != " -"]
property_value_df = property_value_df[property_value_df['property_value'] != ","]
property_value_df = property_value_df[property_value_df['property_value'] != "--"]
property_value_df = property_value_df[property_value_df['property_value'] != "0,0"]
property_value_df = property_value_df[property_value_df['property_value'] != "0,00"]
property_value_df = property_value_df[property_value_df['property_value'] != "0 чол."]
property_value_df = property_value_df[property_value_df['property_value'] != "0 куб.м."]
property_value_df = property_value_df[property_value_df['property_value'] != "0 чол."]
property_value_df = property_value_df[property_value_df['property_value'] != "0 Гкал"]
property_value_df = property_value_df[property_value_df['property_value'] != "0 кВт"]
property_value_df = property_value_df[property_value_df['property_value'] != "0 кв. м"]
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1212614351.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['property_value'] = property_value_df['property_value'].str.strip()

# %%
property_value_df.drop_duplicates()
# Out:
#               id  aimap_id            property property_value  \
# 4              5         3  Кількість поверхів             26
# 5              6         3               Площа       149296.6
# 6              7         4  Кількість поверхів              1
# 7              8         4               Площа          279.4
# 8              9         5  Кількість поверхів              1
# ...          ...       ...                 ...            ...
# 3353509  3650419   3052965           Фундамент          Бетон
# 3353510  3650420   3052965             Підлоги        Ламінат
# 3353511  3650421   3052965            Покриття       Руберойд
# 3353512  3650422   3052965               Сходи        Бетонні
# 3353513  3650423   3052965        Сміттєпровід            Так
#
#          normalize_property
# 4        Кількість поверхів
# 5                     Площа
# 6        Кількість поверхів
# 7                     Площа
# 8        Кількість поверхів
# ...                     ...
# ...

# %%
clean_meters_property_name(property_value_df)
clean_energy_property_name(property_value_df)
clean_area_property_name(property_value_df)
clean_money_property_name(property_value_df)
clean_weight_property_name(property_value_df)
# Out:
# C:\Users\dev-1\Projects\stuff\cleans.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["normalize_property"] = df["normalize_property"].str.replace(
# C:\Users\dev-1\Projects\stuff\cleans.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["normalize_property"] = df["normalize_property"].str.replace(
# C:\Users\dev-1\Projects\stuff\cleans.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["normalize_property"] = df["normalize_property"].str.replace(", тис.кВт час в год", "", flags=re.IGNORECASE)
# C:\Users\dev-1\Projects\stuff\cleans.py:45: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["normalize_property"] = df["normalize_property"].str.replace(
# ...

# %%
property_value_df['normalize_property'] = property_value_df['normalize_property'].str.strip()
property_value_df['normalize_property'] = property_value_df['normalize_property'].str.capitalize()

# %%
property_value_df = property_value_df[property_value_df['normalize_property'] != ""]

# %%
property_value_df["units"] = property_value_df["property_value"]
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1367561054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df["units"] = property_value_df["property_value"]

# %%
# clean_units_2(property_value_df)

# %%
property_value_df['units'] = property_value_df['units'].str.findall(
    r"(\sм\d*$|\sм\d*\W$|м.пог.$|М$|м.пог.м$|шт.\/м$|м.пог.метр$|кв.м$|кв.\sм$|км$|км.пог.$|м.куб|куб\W$|куб.м$|куб.\sм.$|куб.\sм$|куб.метр$|м.куб.|куб.м|\sм\Wкуб\W\/год|тис.куб.м.$|куб|тис.м$|млн.куб.м.$|КУБ.М.$|м.куб.м$|м.куб.метр$|кв.метр$|КВ.М$|КВ.МЕТР$|кв.м\W|метр$|кв$|мм\d*$|тис.кв.год|тис.м3\/рік$|тис.м2$|тис.м2\/рік$|тис.м3$|тис.м\/рікнм$|
П\W$|\sзапр\W\/добу$|\sт\/\sг$|люд\W\/дні$|\W\/г$|\W\sдворівнева\sмансарда$|\sтис\Wгривень$|\sчол\/г$|\sкг\/рік$|\sГДж$|\sучбових\sмісць$|\sкімнат$|\sкімнати$|^тис\WкВт\/рік\s*|^рік\s*|^по\sбензину\s|\sт\/рік\)$|^місць\s|^місткість\W\s|^місткість\s\W\s|^м\s|^м\W\s|^м\d\s|^км\s|км\W\s|^шт\s|^із\sФЕМ\s\W\s|^із\sгумових\sплит\s*\W\s|^чоловік\s|^рекрнструкції\s\W\s|м\d\/с|\sштук$|\sпоста$|\sод\W$|\sмісяця$|\sdBm$|\sз\sурахуванням$|)")
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\2266597484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = property_value_df['units'].str.findall(

# %%
 # property_value_df['units'].explode().unique()
property_value_df['units'] = [[s for s in l if s] for l in property_value_df['units']]
# property_value_df['units'] = [item for item in property_value_df['units'] if item != '']
# property_value_df['units'] = list(filter(None, property_value_df['units']))
property_value_df['units'] = [','.join(map(str, l)) for l in property_value_df['units']]
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1121593460.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = [[s for s in l if s] for l in property_value_df['units']]
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1121593460.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = [','.join(map(str, l)) for l in property_value_df['units']]

# %%
# property_value_df["property"].unique()

# %%
property_value_df['property'] = property_value_df['property'].str.strip()
property_value_df['units'] = property_value_df['units'].replace('', pd.NA).fillna(property_value_df['property'])
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1300307748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['property'] = property_value_df['property'].str.strip()
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1300307748.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = property_value_df['units'].replace('', pd.NA).fillna(property_value_df['property'])

# %%
# property_value_df.loc[property_value_df['units'].str.contains('Площа'), 'units'] = 'кв.м'
# property_value_df.loc[property_value_df['units'].str.contains('Кількість'), 'units'] = 'шт'
# property_value_df.loc[property_value_df['units'].str.contains('Висота'), 'units'] = 'м'
# property_value_df.loc[property_value_df['units'].str.contains("Об'єм"), 'units'] = 'м.куб'
property_value_df['units'] = property_value_df['units'].replace("Будівельний об`єм", "куб.м")
property_value_df['units'] = property_value_df['units'].replace("кількість машиномісць для відвідувачів", "шт")
property_value_df['units'] = property_value_df['units'].replace("Площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("торгова площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа літніх неопалюваних приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа житлового будинку", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("основна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа паркінгу", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа приміщень загального користування", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Кількість приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа однокімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа двокімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Житлова площа однокімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Житлова площа двокімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа забудови ,", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа інших нежитлових приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("погріб літ. 'Е1'", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа покрівлі", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа підземного паркінгу", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Будівельний об'єм (кв. 107)", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Нежитлова площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа торгових приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа основи (забудови)", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа нежитлових будівель об’єкта", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа торгівельних приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Розрахункова площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа приміщень, що підлягають капітальному ремонту", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Основна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Провішування проводів, км.", "км")
property_value_df['units'] = property_value_df['units'].replace("Сарай літ. 'Я'", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа приміщень загального користування", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("загальна площа нежитлових приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("підсобна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Житлова площа приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа однокімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа двокімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа будівлі", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа трикімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Житлова площа трикімнатних квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа паркінгу", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("загальна площа трансформаторної підстанції", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Житлова площа квартр", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("підсобна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Річна потреба в електричній енергії", "кВт/год")
property_value_df['units'] = property_value_df['units'].replace("річна потреба в електричній енергії", "кВт/год")
property_value_df['units'] = property_value_df['units'].replace("Площа забудови", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("допоміжна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("торгівельна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Торгівельна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Основна площа приміщення", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа ремонту ", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа вбудованих, вбудовано-прибудованих та прибудованих приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа житлової частини будинку", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа офісних приміщень, основна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа   торгового залу магазину", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа комерційних приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа забудови, м. кв.", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа забудови", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Житлова площа по проекту", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Будівельний об'єм будівлі", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа складських приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("розрахункова площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа утеплення фасадів", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа забудови паливної", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа дорожнього покриття", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("загальна площа приміщень, що підлягає ремонту", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа ресторану", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа вбудованих приміщень громадського призначення", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("корисна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("загальна площа павільйону літ Б", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа забудови відомчої квартири", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("торгова площа магазину після реконструкції", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Корисна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Допоміжна площа будівлі", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Допоміжна площа", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальний будівельний об'єм", "м3")
property_value_df['units'] = property_value_df['units'].replace("Загальний будівельний об'є", "м3")

property_value_df['units'] = property_value_df['units'].replace("об'єм зберігання зерна", "м3")
property_value_df['units'] = property_value_df['units'].replace("Будівельний об'єм вище відм. 0.00", "м3")
property_value_df['units'] = property_value_df['units'].replace("Будівельний об'єм нижче відм. 0.00", "м3")
property_value_df['units'] = property_value_df['units'].replace("Вузол обліку газу", "м3")
property_value_df['units'] = property_value_df['units'].replace("пропускна здатність людей в год", "люд/год")
property_value_df['units'] = property_value_df['units'].replace("Висота", "м")
property_value_df['units'] = property_value_df['units'].replace("Висота приміщень", "м")
property_value_df['units'] = property_value_df['units'].replace("Загальна довжина", "м")
property_value_df['units'] = property_value_df['units'].replace("Висота будівлі", "м")
property_value_df['units'] = property_value_df['units'].replace("Протяжність об'єкта", "м")
property_value_df['units'] = property_value_df['units'].replace("ОПОРА МЕТАЛЕВА ОЦИНКОВАНА, ВИСОТОЮ 8 МЕТРІВ, ШТ", "шт")
property_value_df['units'] = property_value_df['units'].replace("Ширина узбіччя", "м")
property_value_df['units'] = property_value_df['units'].replace("Ширина земляного полотна", "м")
property_value_df['units'] = property_value_df['units'].replace("Ширина", "м")
property_value_df['units'] = property_value_df['units'].replace("Довжина", "м")
property_value_df['units'] = property_value_df['units'].replace("Ширина проїжджої частини", "м")
property_value_df['units'] = property_value_df['units'].replace("річна потреба в воді", "тис.м3")
property_value_df['units'] = property_value_df['units'].replace("Потужність об'єкта", "Вт")
property_value_df['units'] = property_value_df['units'].replace("Потужність об'єкта,", "Вт")
property_value_df['units'] = property_value_df['units'].replace("Річна потреба в електроенергії", "кВт/год")
property_value_df['units'] = property_value_df['units'].replace("Кількість", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість відвідувачів", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість поверхів", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість машиномісць", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість машино-місць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість трикімнатних квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість чотирикімнатних квартир, квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість п’ятикімнатних квартир, квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Площа вбудованих, вбудовано-прибудованих та прибудованих приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа чотирикімнатних і більше квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("кількість кімнат", "шт")
property_value_df['units'] = property_value_df['units'].replace("Місткість, машиномісць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість житлових кімнат після реконструкції квартири на 10-му поверсі", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість житлових кімнат", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість торгівельних точок", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість створених робочих місць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість робочих місць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість робочих", "шт")
property_value_df['units'] = property_value_df['units'].replace("Місткість (кількість бройлерів)", "тис.місць")
property_value_df['units'] = property_value_df['units'].replace("кількість робочих місць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Загальна кількість працюючих", "шт")
property_value_df['units'] = property_value_df['units'].replace("Загальна кількість працюючих,", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість смуг, смуг", "шт")
property_value_df['units'] = property_value_df['units'].replace("місткість літніх вольєрів, звірів", "шт")
property_value_df['units'] = property_value_df['units'].replace("Потужність об'єкта", "Вт")
property_value_df['units'] = property_value_df['units'].replace("Поверх", "пов")
property_value_df['units'] = property_value_df['units'].replace("поверх", "пов")
property_value_df['units'] = property_value_df['units'].replace("поверховість, поверх", "пов")
property_value_df['units'] = property_value_df['units'].replace("поверховість", "пов")
property_value_df['units'] = property_value_df['units'].replace("Поверх,", "пов")
property_value_df['units'] = property_value_df['units'].replace("Загальна кількість дітей по будівлі", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість однокімнатних квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість паркомісць в паркінгу", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість модулів", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість однокімнатних квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість трикімнатних квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість двокімнатних квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("машино-місць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість чотирикімнатних і більше квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Площа капітального ремонту", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("площа дороги, що підлягає капремонту", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа даху що підлягає ремонту", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа (площа забудови з урахуванням навісу над службовим приміщенням)", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Довжина ділянки", "м")
property_value_df['units'] = property_value_df['units'].replace("Ширина проїзної частини", "м")
property_value_df['units'] = property_value_df['units'].replace("Площа літніх приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Улаштування покриттів товщиною 4 см, 100м2", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Улаштування вирівнювального шару, 100т", "т")
property_value_df['units'] = property_value_df['units'].replace("Корисна площа приміщень", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Площа покриття даху", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна площа квартири №41/3", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("житлова площа квартир", "кв.м")
property_value_df['units'] = property_value_df['units'].replace("Загальна кількість квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Загальна кількість квартир,", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість паркомісць в гаражі", "шт")
property_value_df['units'] = property_value_df['units'].replace("Загальна кількість квартир, квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість трикімнатних квартир, квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість двокімнатних квартир, квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість однокімнатних квартир, квартир", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість працівників", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість блоків", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість смуг руху", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість смуг руху", "шт")
property_value_df['units'] = property_value_df['units'].replace("кількість комнат", "шт")
property_value_df['units'] = property_value_df['units'].replace("Кількість світильників", "шт")
property_value_df['units'] = property_value_df['units'].replace("Ступінь вогнестійкості об’єкту будівництва", "ст")
property_value_df['units'] = property_value_df['units'].replace("Ступінь вогнестійкості будинку", "ст")
property_value_df['units'] = property_value_df['units'].replace("Ступінь вогнестійкості будинку,", "ст")
property_value_df['units'] = property_value_df['units'].replace("Ступінь вогнестійкості", "ст")
property_value_df['units'] = property_value_df['units'].replace("Швидкість", "м/с")
property_value_df['units'] = property_value_df['units'].replace("Радіус", "R")
property_value_df['units'] = property_value_df['units'].replace("Глибина", "м")
property_value_df['units'] = property_value_df['units'].replace("Довжина ділянки дороги, що ремонтується", "м")
property_value_df['units'] = property_value_df['units'].replace("Вартість основних фондів об’єкту будівництва,", "тис.грн.")
property_value_df['units'] = property_value_df['units'].replace("Кошторисна вартість, тис. грн,", "тис.грн.")
property_value_df['units'] = property_value_df['units'].replace("Вага,", "кг")
property_value_df['units'] = property_value_df['units'].replace("ємність кабелю, волокно,", "C")
property_value_df['units'] = property_value_df['units'].replace("пропускна здатність людей в дедь", "люд/день")
property_value_df['units'] = property_value_df['units'].replace("Кількість відвідувачів (чол.)", "чол")
property_value_df['units'] = property_value_df['units'].replace("пропускна спроможність ", "чол/день")
property_value_df['units'] = property_value_df['units'].replace("Загальна кошторисна вартість залишку складає", "тис.грн")
property_value_df['units'] = property_value_df['units'].replace("Кількість створених робочих місць, місць", "шт")
property_value_df['units'] = property_value_df['units'].replace("Корисна площа вбудованих нежитлових приміщень", "тис.грн")
property_value_df['units'] = property_value_df['units'].str.strip()
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\3645596386.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = property_value_df['units'].replace("Будівельний об`єм", "куб.м")
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\
sтис\W\sлюд\Wг$|\s\/г$|^т\/рік\s*|\sлюд\Wдні$|\sтн\/добу$|\sособи$|\sпов\W$|\(\sв\sтому.*\)$|\sв\sтому\sчислі.*$|\sлюдиноднів$|\sпар\/рік$|\sлюд\W\/г$|\sтон\/рік$|\s[\+]мс$|\sтис\WГДж$|\sкВт\Wгод\/рік$|\sнадземних\sта\sцокольний\sповерхи$|\sт\/міс$|\sчол\W\/доб$|\s\W\sмагазин$|\s\W\sсклад$|\Wкафе\Wпекарня$|^\(торгівельна\)\s|^\(місткість\)\s|\sосіб\/добу$|\W\sмлн\Wдал\/рік$|\\tкв\Wметрів$|\\tичніх\\tметрів$|\\t$|\sтон\/добу$|\sт\/г$|^до\s|\sл\/с$|\sлюдино\Wднів$|\sм\d*\/.*$|\sтис\Wгрн\W\/.*$|\sкВт\s.*$|\sМ\WП\W$|\sзапр\W\/добу$|\sт\/\sг$|люд\W\/дні$|\W\/г$|\W\sдворівнева\sмансарда$|\sтис\Wгривень$|\sчол\/г$|\sкг\/рік$|\sГДж$|\sучбових\sмісць$|\sкімнат$|\sкімнати$|^тис\WкВт\/рік\s*|^рік\s*|^по\sбензину\s|\sт\/рік\)$|^місць\s|^місткість\W\s|^місткість\s\W\s|^м\s|^м\W\s|^м\d\s|^км\s|км\W\s|^шт\s|^із\sФЕМ\s\W\s|^із\sгумових\sплит\s*\W\s|^чоловік\s|^рекрнструкції\s\W\s|м\d\/с|\sштук$|\sпоста$|\sод\W$|\sмісяця$|\sdBm$|\sз\sурахуванням$|)")
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\2266597484.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = property_value_df['units'].str.findall(

# %%
property_value_df['units'] = [[s for s in l if s] for l in property_value_df['units']]
property_value_df['units'] = [','.join(map(str, l)) for l in property_value_df['units']]
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\2494670334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = [[s for s in l if s] for l in property_value_df['units']]
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\2494670334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'] = [','.join(map(str, l)) for l in property_value_df['units']]

# %%
property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Будівельний об`є", "Будівельний об`єм")
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1879921262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Будівельний об`є", "Будівельний об`єм")

# %%
# property_value_df['units'].unique()

# %%
# property_value_df['normalize_property'].unique()

# %%
# square = property_value_df.normalize_property.str.contains('площа')

# %%
# property_value_df.loc[square, 'normalize_property'].unique()

# %%
property_value_df["units"] = property_value_df["units"].str.replace("(\(|\)|^,\s|^\s|^,|^\d*|\,$|;|\sІ\s.*|^\/|\sсарай$|\sальтанка.*$|\s0,00м3.*$|\s0\/00м3.*$|\sІІ.*$|:$|\sнавколо віконних$|\sскладських приміщень$|\sльох\/\sнавіс)", "", flags=re.IGNORECASE)
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1404391057.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   property_value_df["units"] = property_value_df["units"].str.replace("(\(|\)|^,\s|^\s|^,|^\d*|\,$|;|\sІ\s.*|^\/|\sсарай$|\sальтанка.*$|\s0,00м3.*$|\s0\/00м3.*$|\sІІ.*$|:$|\sнавколо віконних$|\sскладських приміщень$|\sльох\/\sнавіс)", "", flags=re.IGNORECASE)
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1404391057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
property_value_df["units"] = property_value_df["units"].str.replace(",", "/", flags=re.IGNORECASE)
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\2348722740.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df["units"] = property_value_df["units"].str.replace(",", "/", flags=re.IGNORECASE)

# %%
# property_value_df['units'].unique()

# %%
property_value_df['units'][property_value_df.normalize_property == "Поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість готельного корпусу"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість вчительської"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість гостьогового будинку"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість складської будівлі"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверх розташування"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі після реконструкції, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість топкової"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі кафе з прибудовою допоміжних приміщень та сауни після реконструкції, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість складу"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверх каремонту, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість котельні"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість сараю"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будинку відпочинку"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість до реконструкції"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість другого будинку відпочинку, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість до реконструкції, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість адміністративної будівлі"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверх розташування в межах кап. репонту, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість котедж"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість тп, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі добудови"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будель охоронця, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість, поверх."] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість магазину"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі супермаркету з прибудовою"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі кпп"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будинків (1"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість магазину-закусочної"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі пункту охорони"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість приміщення, яке підлягає капітальному ремонту, етажність"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість адміністративно-побутової будівлі"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість трансформаторної підстанції"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість існуючого житлового будинку, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверх, що підлягає реконструкції, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість (в межах реконструкції), поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будинків"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість госпбудівлі, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість будівлі охорони"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість, в т.ч. в межах проектування, поверх"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховість добудованого складу"] = "пов."
property_value_df['units'][property_value_df.normalize_property == "Поверховісь, кількість"] = "шт."
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\4073104611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'][property_value_df.normalize_property == "Поверх"] = "пов."
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\4073104611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'][property_value_df.normalize_property == "Поверх"] = "пов."
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\4073104611.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
property_value_df['units'][property_value_df.normalize_property == "Висота"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота будівлі"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота приміщень"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота поверху"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота приміщення"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота огородження"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота приміщень після ремонту"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота навісу"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота поверху ангару"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота поверху складських приміщень"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота бар'єрного огородження"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота поверха"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота будівлі пункту охорони"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота боксу"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота фазового центру антен"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота фазового центру антени"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота будинку"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота фазового центру\nантени"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота фазового центру антени dcs+lte-1800/ umts-2100"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота фазового центру антени dcs+lte-1800/umts-2100"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота встановлюльного обладнання"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота приміщень до реконструкції"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Висота будівлі супермаркету з прибудовою"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Загальна протяжність"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина проїзної частини"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина тротуару ліворуч за ходом кілометражу"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина тротуару праворуч за ходом кілометражу"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина проїзної частини перед спорудою"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина проїзної частини за спорудою"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина проїжджої частини"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Габарит по ширині"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Довжина проїзної частини"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Дорожня розмітка"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Довжина ділянки дороги, що ремонтується"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Будівельна довжина"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Довжина"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Загальна довжина"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Гранична висота"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Протяжність об'єкта"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина узбіччя"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Улаштування водопровідного колектору"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Самонесучий ізольований провід сіп"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Довжина проектованої ділянки"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Швидкість"] = "м/с"
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\772150183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'][property_value_df.normalize_property == "Висота"] = "м"
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\772150183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'][property_value_df.normalize_property == "Висота"] = "м"
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\772150183.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
property_value_df['units'][property_value_df.normalize_property == "Місткість"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість восьмикімнатних і більше"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість боксомість"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Встановлення футбольних воріт so-9.05"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Установка світильників"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Улаштування водоскидних споруд з проїжджої частини з залізобетонних водоприймальних колодязів"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість наземних резервуарів свг"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість підземних резервуарів свг"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість контейнерів для збору тпв"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість встановленних фотомодулів"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість встановлених інвенторів"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість чотирикімнатних і більше"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість п’ятикімнатних"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "загальна кількість шаф управління зовнішнім освітленням"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Площа аптеки"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Місткість людей"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість відвідувачів"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Сила струму"] = "А"
property_value_df['units'][property_value_df.normalize_property == "Ступінь вогнестійкості об’єкту будівництва"] = "ст"
property_value_df['units'][property_value_df.normalize_property == "Кількість двокімнатних"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість однокімнатних"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Кількість трикімнатних"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Ступінь вогнестійкості"] = "ст"
property_value_df['units'][property_value_df.normalize_property == "Ступінь вогнестійкості об’єкту будівництва"] = "ст"
property_value_df['units'][property_value_df.normalize_property == "Об'єм будівлі"] = "м3"
property_value_df['units'][property_value_df.normalize_property == "Річне споживання теплової енергії"] = "Гкал/рік"
property_value_df['units'][property_value_df.normalize_property == "Потужність"] = "кВт"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа чотирикімнатних"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Житлова площа чотирикімнатних"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа афальтобетонного покриття"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа інших нежитлових приміщень"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа тротуару"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа торгового залу"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа благоустрою"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа будинку"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Внутрішнє оздоблення приміщень"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа основи (забудови) будівлі автоцентру hyunda"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа основи (забудови) будівлі автоцентру kia"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа основи (забудови) будівлі автоцентру mg"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа основи (забудови) будівлі автомийки"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа будівель"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа вбудованих нежитлових приміщень пенршого поверху"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Гараж"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Ємність"] = "Ф"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа до реконструкції"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Погріб"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа асфальтування"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа афальтобетонного покриття"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна довжина трубопроводу  із нержавіючої сталі"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа магазину"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Торговельна площа"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна житлова площа"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна площа будинку"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "опалювальна площа будівлі"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Вартість"] = "грн."
property_value_df['units'][property_value_df.normalize_property == "Напруга"] = "В"
property_value_df['units'][property_value_df.normalize_property == "Витрати на будівельні роботи"] = "грн"
property_value_df['units'][property_value_df.normalize_property == "Витрати на машини, обладнання та інвентар"] = "грн"
property_value_df['units'][property_value_df.normalize_property == "Будівельний об'є"] = "куб.м"
property_value_df['units'][property_value_df.normalize_property == "Будівельний об'єм вище відм. 0.00"] = "куб.м"
property_value_df['units'][property_value_df.normalize_property == "Будівельний об'єм нижче відм. 0.00"] = "куб.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна кошторисна вартість будівництва, в поточних цінах станом на червень 2020 р. тис. грн."] = "тис.грн"
property_value_df['units'][property_value_df.normalize_property == "Ємність охолоджувальних камер кишкосировини, т."] = "т"
property_value_df['units'][property_value_df.normalize_property == "Будівельний обє"] = "куб.м"
property_value_df['units'][property_value_df.normalize_property == "Площа ділянки (га)"] = "га"
property_value_df['units'][property_value_df.normalize_property == "пропускна спроможнічть, чол./доба"] = "чол./доба"
property_value_df['units'][property_value_df.normalize_property == "площа забудови будівлі з навісом"] = "куб.м"
property_value_df['units'][property_value_df.normalize_property == "житлова площа"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Комплексна трансформаторна підстанція, комплект."] = "комплект"
property_value_df['units'][property_value_df.normalize_property == "ступень вогнестійкості"] = "ст"
property_value_df['units'][property_value_df.normalize_property == "річна кількість електричної енергії, яку виробляють сонячні модулі, кВт/год"] = "кВт/год"
property_value_df['units'][property_value_df.normalize_property == "Трудомісткість будівництва"] = "люд.-дні"
property_value_df['units'][property_value_df.normalize_property == "Кількість транспортних"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Площа капітального ремонту фасаду"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Протяжність трубопроводу"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Житлова площа чотирикімнатних і більше"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа допоміжних приміщень"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Місткість, кіл./день"] = "кіл./день"
property_value_df['units'][property_value_df.normalize_property == "Житлова площа чотирикімнатних і більше"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа покриття проїзної частини"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Загальна кількість приміщень"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Площа утеплення перекриття"] = "кв.м"
property_value_df['units'][property_value_df.normalize_property == "Трудомісткість будівництва"] = "люд/дн"
property_value_df['units'][property_value_df.normalize_property == "Кількість створених робочих"] = "шт"
property_value_df['units'][property_value_df.normalize_property == "Довжина ділянки"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Глибина"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Ширина земляного полотна"] = "м"
property_value_df['units'][property_value_df.normalize_property == "Радіатор біметалічний, секцій"] = "секцій"
property_value_df['units'][property_value_df.normalize_property == "Загальний будівельний об'єм"] = "куб.м"
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1494888524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'][property_value_df.normalize_property == "Місткість"] = "шт"
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1494888524.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_value_df['units'][property_value_df.normalize_property == "Місткість"] = "шт"
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1494888524.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
property_value_df = property_value_df[property_value_df['normalize_property'] != "У тому числі"]

# %%
property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Будівельний об`є", "Будівельний об`єм")
property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Будівельний обє", "Будівельний об`єм")
property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Загальний будівельний об'є", "Загальний будівельний об'єм")
property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Радіатор біметалічний, секцій", "Радіатор біметалічний")
property_value_df['normalize_property'] = property_value_df['normalize_property'].replace("Об`є", "Об`єм")

# %%
property_value_df["property_value"] = property_value_df["property_value"].str.replace("(\sм\d*$|\sм\d*\W$|м.пог.$|М$|м.пог.м$|шт.\/м$|м.пог.метр$|кв.м$|кв.\sм$|км$|км.пог.$|м.куб|куб\W$|куб.м$|куб.\sм.$|куб.\sм$|куб.метр$|м.куб.|куб.м|\sм\Wкуб\W\/год|тис.куб.м.$|куб|тис.м$|млн.куб.м.$|КУБ.М.$|м.куб.м$|м.куб.метр$|кв.метр$|КВ.М$|КВ.МЕТР$|кв.м\W|метр$|кв$|мм\d*$|тис.кв.год|тис.м3\/рік$|тис.м2$|тис.м2\/рік$|тис.м3$|тис.м\/рікнм$|Кв.М$|м.п$|см\d*$|тис.кв.м$|тис$|тис.кв.год.$|п.м.$|шт$|га$|Вт$|.шт.$|кВТ\/шт$|млн.м\d*$|тис.м\d*$|тис.м.куб\/рік$|м.куб.\/год$|куб\/добу$|м.куб.\/рік$|а\/м$|пог.м$|кВт$|кВт\год$|\sт$|\sтон$|тонн$|тонн.в$|тонн.в.рік$|тис.т$|тис.тонн$|тис.тонн.$|тис.тонн.в$|тис.тонн.в.рік$|т\/рік$|тонн\/міс$|кг$|тис.ум.тон$|тонн в рік$|тонн\/рік$|м.2$|тис. голів$|грам$|\sг$|маса$|місце$|кг\/міс$|тис.кВтгод|м.кв|тис. грн$|тис. кВт\Wгод|років$|тис.грн$|тис.грн\W$|тис.грн\W$од\W*$|\sпалетомісць$|\sМВт$|\\r\\n\s*|\sз\sмансардою$|\sповерх$|\Wцокольний\Wмансардний$|\sміс\W$|\Wмансарда$|\Wманса.*$|\sз\sпідвало$|\sм.\sкв.$|\sлюд\/г.*$|\s\(у.*\)$|\s\(\)$|\(\)$|\sкв.$|\Wй$|\sміс$|\sпост$|\Wпідвал$|\s\(\d*\W.*\)$|\s\(|[\+].*$|\sчол\W$|\sкг\/доба$|\s\(.*\)$|в т.ч загальна площа житлової частини - 228,60 м2, загальна площа магазину - 215,10$|\sчол$|\sтонн\/добу$|^м\/п\s|\sучнів$|\sчол\/добу$|\sм\d*\/година$|\sднів$|\sм.п.$|міс.$|\sавто\/доба$|\sкВА$|\sповерхи$|\sповерхів$|\sмісяць$|\s\W\sторгова$|\sкВт\Wг$|\sлюд\/дн$|\sмісяці$|\sм\d*$|\sмісць$|\sдітей$|\sлюдини$|\sм\Wв$|\sмісяців$|
|\W\sв\sт\Wч\W.*|^всього\W\s|\W\s\d\sпусковий.*|^всього\s\W\s|\s*люд\/днів$|\sчол\/год\W$|\sодиниці$|вбудовані\sприміщення 3\sповерх\sжитлового\sбудинку\)$|\sпов$|\sчоловік$|секція.*$|\sтис\W\sлюд\W+$|\sз\sпідвалом\sта\sтехнічним.*$|\s[.]$|^потужність\sпанелей\s|\sз\sтехповерхом\sта\sкабельним.*$|\(будівля\s*.*\)$|\(футбольне\sполе\)$|в\sмежах\sреконструкції\)$|\sдо\/після\s.*$|\sод\W$|осіб\/годину$|\sкомплектів\/добу$|^кількість\sдітей\sв\sбудівлі\sдитячого\sсадка\s\W\s|\sвідвідувачів$|\sмашин$|\sчол\/зміна$|\s\/добу$|\sЛЮД\WДНІВ$|Л\/С$|в\sт\W\sч\W$|чол\W$|^№\d*\s\W\s|^№\d*|^№|^квартири\s№\d*\s\W\s|\($|з$|\sголів\sсвиней.*$|останній$|Допоміжна\sплоща.*$|^котельні\s\W\s|^фундамент\sдимової\sтруби\s\W\s|^будівлі\sкотельні\s\W\s|^розрахункова\sпродуктивність\sкотельні\s\W\s*|\sГкал$|^Загальна\sпротяжність\s*п\/м\s*|\sблоків$|\sчол\/доба$|\sмашино$|частк\W\)$|undefined$|площа капітального ремонту приміщень\)$|\s\W\sавтосервіс$|\s\W\sмийка$|\sліжкомісць$|\sробітників$|\sдекалітри$|\sмм\W$|\sз\sцоколем\s.*$|^житлових\s*\W\s|^підвал\W\s|\sт\/доба$|\sліжок$|\sумовних\sремонтів$|\sдосліджень$|\sлюд\Wднів$|^мереж\sводовідведення\s\W\s|^електрокабелю\s\W\s|^мереж\sводопостачання\s\W\s|адміністративної\sбудівлі\)$|нежитлових\sвбудовано\Wприбудованих\sприміщень\sгромадського\sпризначення\)$|адміністративної\sбудівлі\sз\sприбудовою\)$|дру$|п\W$|\d\Wа\sчерга\s|\sз\sнадбудовою$|\sголів\sВРХ$|\s\W\sмедичний\sцент$|\W\sжитлового\sбудинку$|\W\sжитловий\sбудинок$|\sТА$|\sз\sцокольни.*$|^в\sт\Wч\W\s|виробнича\sбудівля\)$|будівля\sпіскоструминної\sдільниці\)$|\sтон\sпару\/годину$|\sв\sтри\sзміни$|(Загальна|Допоміжна|Корисна)\sплоща\sпідвальних\sприміщень\)$|місць\sдля\sсвиней$|\sмашино\Wмісць$|^Бювет.*\s|^Мостіння\s\W\s|^прокладання\sмережі\s*\W\s|\sк$|та\sантресоль$|)", "", flags=re.IGNORECASE)
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\3777860388.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
property_value_df["property_value"].unique()

# %%
property_value_df["comments"] = ""

# %%
property_value_df["comments"] = np.where(property_value_df['units'] == '', property_value_df['property_value'],property_value_df['comments'])

# %%
property_value_df["comments"].unique()

# %%
# property_value_df.to_csv("C:/Users/dev-1/Projects/stuff/result.csv")

# %%
# / м2

# %%
property_value_df["property_value"].unique()
# property_value_df["property_value"].str.isdigit()
# Out:
# array(['26', '149296.6', '1', ..., '200.92', '60.49', '3141.72'],
#       dtype=object)

# %%
|Л\/С$|в\sт\W\sч\W$|чол\W$|^№\d*\s\W\s|^№\d*|^№|^квартири\s№\d*\s\W\s|\($|з$|\sголів\sсвиней.*$|останній$|Допоміжна\sплоща.*$|^котельні\s\W\s|^фундамент\sдимової\sтруби\s\W\s|^будівлі\sкотельні\s\W\s|^розрахункова\sпродуктивність\sкотельні\s\W\s*|\sГкал$|^Загальна\sпротяжність\s*п\/м\s*|\sблоків$|\sчол\/доба$|\sмашино$|частк\W\)$|undefined$|площа капітального ремонту приміщень\)$|\s\W\sавтосервіс$|\s\W\sмийка$|\sліжкомісць$|\sробітників$|\sдекалітри$|\sмм\W$|\sз\sцоколем\s.*$|^житлових\s*\W\s|^підвал\W\s|\sт\/доба$|\sліжок$|\sумовних\sремонтів$|\sдосліджень$|\sлюд\Wднів$|^мереж\sводовідведення\s\W\s|^електрокабелю\s\W\s|^мереж\sводопостачання\s\W\s|адміністративної\sбудівлі\)$|нежитлових\sвбудовано\Wприбудованих\sприміщень\sгромадського\sпризначення\)$|адміністративної\sбудівлі\sз\sприбудовою\)$|дру$|п\W$|\d\Wа\sчерга\s|\sз\sнадбудовою$|\sголів\sВРХ$|\s\W\sмедичний\sцент$|\W\sжитлового\sбудинку$|\W\sжитловий\sбудинок$|\sТА$|\sз\sцокольни.*$|^в\sт\Wч\W\s|виробнича\sбудівля\)$|будівля\sпіскоструминної\sдільниці\)$|\sтон\sпару\/годину$|\sв\sтри\sзміни$|(Загальна|Допоміжна|Корисна)\sплоща\sпідвальних\sприміщень\)$|місць\sдля\sсвиней$|\sмашино\Wмісць$|^Бювет.*\s|^Мостіння\s\W\s|^прокладання\sмережі\s*\W\s|\sк$|та\sантресоль$|\s\/\s|\s\(га\)\W$|^[.]|)

# %%
property_value_df = property_value_df[property_value_df['property_value'] != ""]

# %%
property_value_df['property_value'] = property_value_df['property_value'].str.strip()

# %%
property_value_df["property_value"] = property_value_df["property_value"].str.replace("(\(\d\/\d\/\d\)$|\(\d$|)|\(\d\/\d\/\d\/\d\)$", "", flags=re.IGNORECASE)
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\3117118875.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   property_value_df["property_value"] = property_value_df["property_value"].str.replace("(\(\d\/\d\/\d\)$|\(\d$|)|\(\d\/\d\/\d\/\d\)$", "", flags=re.IGNORECASE)

# %%
property_value_df = property_value_df[property_value_df['property_value'] != ""]

# %%
property_value_df[property_value_df['property_value'].str.contains('м3')]
# Out:
#               id  aimap_id                                           property  \
# 2599968  2798992   1307944                                 Потужність об'єкта
# 2653428  2852452   1343067                               річна потреба у воді
# 2653492  2852516   1343084         Обсяг переробки твердих побутових відходів
# 2665530  2864554   1350972                                 Потужність об'єкта
# 2683695  2882719   1394369                        Загальний будівельний об'єм
# 2694819  2893843   1447990                               річна потреба у воді
# 2709308  2908332   1627195                                 Потужність об'єкта
# 2744117  2943141   1870697                                 Потужність об'єкта
# 2994430  3201642   2567738                                Потужність об'єкта,
# 3118412  3388072   2959749                                Потужність об'єкта,
# 3217428  3487088   2862772                        Загальний будівельний об'єм
# ...

# %%
property_value_df["property_value"] = property_value_df["property_value"].str.replace("(
т\sсвітильників$|\sшт\/мп$|\sштуки$|^Трансформатори\sструму\s|кВ\s\W\d\sшт\W\W\s.*$|кВ\s*\W\d\sшт\W\W\s.*$|\sшт\W\W.*$|^Вимикач\sтрьохполюсний\sелегазовий\sнапруга\s|\sкВ\W\W\s\d|шт\)\sколодязів$|Нове\sбудівництво\sжитлового\sбудинку\sз\sвбудовано-прибудованими\sнежитловими\sприміщеннями\sза\sадресою:\sКиївська\sобласть,\sс.\sПетропалівська Борщагівка,\sвул.\sКаштанова,\sбуд.\s2$|загальна\sкошторисна\sвартість$|^квартири\s\W\s|квартира\)$|\W\s.*$|\sквадратних\sметрів$|\sкварти$|\sквм\W$|\sкв\W\sметрів$|\sметри\sквадратні$|\sметрів\sквадратних$|\sзагальна\sплоща\sквартири$|^мансарда\sквартири\s|\sповерху$|\sосіб\/зміну$|\sосіб\/день$|осіб$|\sосіб\/зміна$|\sосібІ\s.*$|\sлюд\Wг$|\sлюд\W*$|\sтис\Wлюд\Wг$|\sтис\Wлюд\Wгод\W$|люд$|\sтис\Wлюд\W\Wгод\W$|^люд\W{2}|\sробочих\sпости$|\sтис\WкВт\Wгод\/$|\sметри$|\sмашиномісць\sс\/г\sтехніки$|секції\s\d$|\sавт\/$|\sповерх\W$|\sр\/$|\sкат$|\Wкімнатних$|)", "", flags=re.IGNORECASE)
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\1702243047.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
property_value_df[property_value_df['property_value'].str.contains('м3')]
# Out:
# Empty DataFrame
# Columns: [id, aimap_id, property, property_value, normalize_property, units]
# Index: []

# %%
property_value_df["property_value"] = property_value_df["property_value"].str.replace("(\sм\d|добу$|\d\W\d*\sмм\d\s\W\s)", "", flags=re.IGNORECASE)
# Out:
# C:\Users\dev-1\AppData\Local\Temp\ipykernel_4356\3991790967.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   property_value_df["property_value"] = property_value_df["property_value"].str.replace("(\sм\d|добу$|\d\W\d*\sмм\d\s\W\s)", "", flags=re.IGNORECASE)

# %%
property_value_df[property_value_df['property_value'].str.contains('люд')]
# Out:
#               id  aimap_id                           property  \
# 2575646  2774670   1291943                 Потужність об'єкта
# 2583342  2782366   1296767             Пропускна спроможність
# 2585063  2784087   1297944       Загальна кількість працюючих
# 2602771  2801795   1309690         Трудомісткість будівництва
# 2626419  2825443   1325396                 Потужність об'єкта
# 2659199  2858223   1347038  Кількість створених робочих місць
# 2710557  2909581   1640217         Трудомісткість будівництва
# 2768554  2967578   2092978       Загальна кількість працюючих
# 2782408  2981432   2189147         Трудомісткість будівництва
# 2785947  2984971   2220287         Трудомісткість будівництва
# 2844888  3043912   2419048      Загальна кількість працюючих,
# 3026805  3234017   2711464        Трудомісткість будівництва,
# 3029714  3236926   2729311               Пропускна здатність,
# 3031028  3238240   2739039        Трудомісткість будівництва,
# ...

# %%
property_value_df = property_value_df[property_value_df['property_value'] != ""]
property_value_df = property_value_df[property_value_df['property_value'] != "0"]
property_value_df = property_value_df[property_value_df['property_value'] != "0,0"]
property_value_df = property_value_df[property_value_df['property_value'] != "0,000"]

# %%
property_value_df["property_value"].unique()
# Out:
# array(['26', '149296.6', '1', ..., '200.92', '60.49', '3141.72'],
#       dtype=object)
